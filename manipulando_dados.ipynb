# %%
import pandas as pd

# %%
dados_csv = pd.read_csv('data_inicial.csv')
dados_csv
# Out:
#                         nome  idade                              email   uf  \
# 0                 Ian da Luz     18              ana-luiza96@gmail.com   PI
# 1        Maria Luiza Cardoso     21                laisramos@ig.com.br   GO
# 2           Heloísa Teixeira     19                 laura00@mendes.net   RR
# 3              Luiza Correia     35                 alana55@bol.com.br   PE
# 4              Alice da Mata     34                zda-mata@bol.com.br   GO
# 5               Alexia Viana     35       ana-juliapeixoto@hotmail.com   MG
# 6         Sra. Helena Aragão     54                    hlopes@souza.br   RO
# 7             Augusto Vieira     50          almeidamarcelo@barros.com   AC
# 8                Isis Aragão     18                    xrocha@costa.br   RN
# 9           Gabriela da Mota     45               vianapedro@gmail.com   SE
# 10      João Guilherme Ramos     48               omoraes@silveira.com   RS
# ...

# %%
# passando dados para um data frame
df = pd.DataFrame(dados_csv)
df.head()
# Out:
#                   nome  idade                   email   uf   genero_musical  \
# 0           Ian da Luz     18   ana-luiza96@gmail.com   PI       Eletrônica
# 1  Maria Luiza Cardoso     21     laisramos@ig.com.br   GO              Axé
# 2     Heloísa Teixeira     19      laura00@mendes.net   RR  Música clássica
# 3        Luiza Correia     35      alana55@bol.com.br   PE          Country
# 4        Alice da Mata     34     zda-mata@bol.com.br   GO  Música clássica
#
#   linguagem
# 0   Python
# 1     Java
# 2     Java
# 3     Java
# 4     Java

# %%
df['nome'].head()
# Out:
# 0             Ian da Luz
# 1    Maria Luiza Cardoso
# 2       Heloísa Teixeira
# 3          Luiza Correia
# 4          Alice da Mata
# Name: nome, dtype: object
