# %%
import pandas as pd

reviews = pd.read_csv('02_data.csv')
reviews
# Out:
#                       nome  idade                           email  \
# 0              Samuel Melo     27       goncalvesdanilo@gmail.com
# 1         Henrique da Mata     60         jesusisadora@uol.com.br
# 2              Luigi Cunha     39            acarvalho@uol.com.br
# 3     Dra. Fernanda Novaes     29      ribeiropietra@yahoo.com.br
# 4         Joaquim Ferreira     60                 emelo@gmail.com
# ..                     ...    ...                             ...
# 195  Vitor Gabriel da Cruz     32              jbarros@uol.com.br
# 196       Letícia Silveira     20           jsilveira@pereira.org
# 197    Vitor Hugo Carvalho     65       rodriguesbreno@correia.br
# 198    Davi Lucas Nogueira     56        ada-conceicao@uol.com.br
# 199    Luiz Otávio Azevedo     43  maria-sophianogueira@lopes.net
#
#                   estado genero_musical linguagem
# 0         Espírito Santo          Blues    Python
# 1               Rondônia           Jazz      Java
# ...

# %%
# retornando uma coluna

reviews.email
# Out:
# 0           goncalvesdanilo@gmail.com
# 1             jesusisadora@uol.com.br
# 2                acarvalho@uol.com.br
# 3          ribeiropietra@yahoo.com.br
# 4                     emelo@gmail.com
#                     ...
# 195                jbarros@uol.com.br
# 196             jsilveira@pereira.org
# 197         rodriguesbreno@correia.br
# 198          ada-conceicao@uol.com.br
# 199    maria-sophianogueira@lopes.net
# Name: email, Length: 200, dtype: object

# %%
reviews['email']
# Out:
# 0           goncalvesdanilo@gmail.com
# 1             jesusisadora@uol.com.br
# 2                acarvalho@uol.com.br
# 3          ribeiropietra@yahoo.com.br
# 4                     emelo@gmail.com
#                     ...
# 195                jbarros@uol.com.br
# 196             jsilveira@pereira.org
# 197         rodriguesbreno@correia.br
# 198          ada-conceicao@uol.com.br
# 199    maria-sophianogueira@lopes.net
# Name: email, Length: 200, dtype: object

# %%
# retorna o item do index especificado
reviews['email'][0]
# Out:
# 'goncalvesdanilo@gmail.com'

# %%
# ILOC

# retorna o primeiro item 
reviews.iloc[0]
# Out:
# nome                            Samuel Melo
# idade                                    27
# email             goncalvesdanilo@gmail.com
# estado                       Espírito Santo
# genero_musical                        Blues
# linguagem                            Python
# Name: 0, dtype: object

# %%
# Retorna todos da coluna 0
reviews.iloc[:, 0]
# Out:
# 0                Samuel Melo
# 1           Henrique da Mata
# 2                Luigi Cunha
# 3       Dra. Fernanda Novaes
# 4           Joaquim Ferreira
#                ...
# 195    Vitor Gabriel da Cruz
# 196         Letícia Silveira
# 197      Vitor Hugo Carvalho
# 198      Davi Lucas Nogueira
# 199      Luiz Otávio Azevedo
# Name: nome, Length: 200, dtype: object

# %%
# retorna os 3 primeiros da coluna 0
reviews.iloc[:3, 0]
# Out:
# 0         Samuel Melo
# 1    Henrique da Mata
# 2         Luigi Cunha
# Name: nome, dtype: object

# %%
# do index 5 até o index 10 da coluna 0
reviews.iloc[5:10, 0]
# Out:
# 5         Nicolas da Luz
# 6           Alexia Gomes
# 7    Sra. Catarina Viana
# 8            Júlia Sales
# 9            Igor Farias
# Name: nome, dtype: object

# %%
# selecionar por index
reviews.iloc[[1, 10, 7], 0]
# Out:
# 1        Henrique da Mata
# 10          Isaac da Mata
# 7     Sra. Catarina Viana
# Name: nome, dtype: object

# %%
# Retorna os 5 ultimos
reviews.iloc[-5:]
# Out:
#                       nome  idade                           email  \
# 195  Vitor Gabriel da Cruz     32              jbarros@uol.com.br
# 196       Letícia Silveira     20           jsilveira@pereira.org
# 197    Vitor Hugo Carvalho     65       rodriguesbreno@correia.br
# 198    Davi Lucas Nogueira     56        ada-conceicao@uol.com.br
# 199    Luiz Otávio Azevedo     43  maria-sophianogueira@lopes.net
#
#                   estado genero_musical linguagem
# 195              Sergipe     Eletrônica    Python
# 196  Rio Grande do Norte        Hip Hop    Python
# 197                Bahia         Pagode    Python
# 198         Minas Gerais           Rock      Java
# 199                Amapá           Funk      Java

# %%
# LOC

# index 0 da coluna nome
reviews.loc[0, 'nome']
# Out:
# 'Samuel Melo'

# %%
# Retornar apenas as colunas especificadas

reviews.loc[:, ['nome', 'idade', 'linguagem']]
# Out:
#                       nome  idade linguagem
# 0              Samuel Melo     27    Python
# 1         Henrique da Mata     60      Java
# 2              Luigi Cunha     39    Python
# 3     Dra. Fernanda Novaes     29      Java
# 4         Joaquim Ferreira     60      Java
# ..                     ...    ...       ...
# 195  Vitor Gabriel da Cruz     32    Python
# 196       Letícia Silveira     20    Python
# 197    Vitor Hugo Carvalho     65    Python
# 198    Davi Lucas Nogueira     56      Java
# 199    Luiz Otávio Azevedo     43      Java
#
# [200 rows x 3 columns]

# %%
# Manipulando por index

# trocando uma coluna por index
reviews.set_index('nome')
# Out:
#                        idade                           email  \
# nome
# Samuel Melo               27       goncalvesdanilo@gmail.com
# Henrique da Mata          60         jesusisadora@uol.com.br
# Luigi Cunha               39            acarvalho@uol.com.br
# Dra. Fernanda Novaes      29      ribeiropietra@yahoo.com.br
# Joaquim Ferreira          60                 emelo@gmail.com
# ...                      ...                             ...
# Vitor Gabriel da Cruz     32              jbarros@uol.com.br
# Letícia Silveira          20           jsilveira@pereira.org
# Vitor Hugo Carvalho       65       rodriguesbreno@correia.br
# Davi Lucas Nogueira       56        ada-conceicao@uol.com.br
# Luiz Otávio Azevedo       43  maria-sophianogueira@lopes.net
#
#                                     estado genero_musical linguagem
# nome
# Samuel Melo                 Espírito Santo          Blues    Python
# Henrique da Mata                  Rondônia           Jazz      Java
# ...

# %%
# Pegar itens da coluna apenas com o valor igual ao especificado (retorna True e false)
reviews.linguagem == 'Python'
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 195     True
# 196     True
# 197     True
# 198    False
# 199    False
# Name: linguagem, Length: 200, dtype: bool

# %%
# Exibir apenas os campos se a condição for True
reviews.loc[reviews.linguagem == 'Python']
# Out:
#                              nome  idade                      email  \
# 0                     Samuel Melo     27  goncalvesdanilo@gmail.com
# 2                     Luigi Cunha     39       acarvalho@uol.com.br
# 6                    Alexia Gomes     37   kamillycosta@hotmail.com
# 7             Sra. Catarina Viana     61  benicioda-luz@hotmail.com
# 8                     Júlia Sales     31     sda-rocha@monteiro.com
# ..                            ...    ...                        ...
# 193               Lavínia Moreira     35       salesesther@melo.net
# 194  Sr. Gustavo Henrique Barbosa     38  luanacostela@carvalho.net
# 195         Vitor Gabriel da Cruz     32         jbarros@uol.com.br
# 196              Letícia Silveira     20      jsilveira@pereira.org
# 197           Vitor Hugo Carvalho     65  rodriguesbreno@correia.br
#
#                   estado genero_musical linguagem
# 0         Espírito Santo          Blues    Python
# ...

# %%
# Exibir apenas os campos se a condição for True
# E
reviews.loc[(reviews.linguagem == 'Python') & (reviews.genero_musical == 'Blues')]
# Out:
#                    nome  idade                       email  \
# 0           Samuel Melo     27   goncalvesdanilo@gmail.com
# 66      Lavínia Azevedo     58  vitoriaalmeida@correia.org
# 75          Elisa Viana     56   joao-felipe59@hotmail.com
# 98        Vitor da Cruz     40        gabriel36@barbosa.br
# 131  Pedro Miguel Costa     46     ferreirabreno@ig.com.br
# 170  Pedro Miguel Porto     44          xbarbosa@ig.com.br
#
#                   estado genero_musical linguagem
# 0         Espírito Santo          Blues    Python
# 66                 Bahia          Blues    Python
# 75   Rio Grande do Norte          Blues    Python
# 98                 Bahia          Blues    Python
# 131                Goiás          Blues    Python
# 170       Espírito Santo          Blues    Python

# %%
# Exibir apenas os campos se a condição for True
# OU
reviews.loc[(reviews.linguagem == 'Java') | (reviews.genero_musical == 'Blues')]
# Out:
#                      nome  idade                            email  \
# 0             Samuel Melo     27        goncalvesdanilo@gmail.com
# 1        Henrique da Mata     60          jesusisadora@uol.com.br
# 3    Dra. Fernanda Novaes     29       ribeiropietra@yahoo.com.br
# 4        Joaquim Ferreira     60                  emelo@gmail.com
# 5          Nicolas da Luz     46                julia99@castro.br
# ..                    ...    ...                              ...
# 188   Sr. Thales da Costa     57           andreoliveira@dias.com
# 189         Raquel Santos     40  goncalvesmaria-clara@vieira.com
# 191       Emanuelly Alves     30              rda-luz@hotmail.com
# 198   Davi Lucas Nogueira     56         ada-conceicao@uol.com.br
# 199   Luiz Otávio Azevedo     43   maria-sophianogueira@lopes.net
#
#                estado genero_musical linguagem
# 0      Espírito Santo          Blues    Python
# 1            Rondônia           Jazz      Java
# ...

# %%
# Pegar apenas os valoes desejados de dentro de uma coluna
reviews.loc[reviews.genero_musical.isin(['Jazz', 'Blues'])]
# Out:
#                          nome  idade                          email  \
# 0                 Samuel Melo     27      goncalvesdanilo@gmail.com
# 1            Henrique da Mata     60        jesusisadora@uol.com.br
# 9                 Igor Farias     37           vda-cunha@uol.com.br
# 15        Ana Carolina Fogaça     27    rafaelacavalcanti@lopes.com
# 16              Melissa Porto     62          rochapaulo@uol.com.br
# 18             Stephany Pinto     39           luiz-miguel36@da.com
# 36             Dr. João Viana     66            lorenzo70@santos.br
# 44                Laís Santos     60             kgomes@hotmail.com
# 50              Eduardo Costa     56          melissasilva@dias.com
# 53               Elisa Farias     27               raul81@ig.com.br
# 60           Benício Monteiro     21       vianagabriela@uol.com.br
# 66            Lavínia Azevedo     58     vitoriaalmeida@correia.org
# 70    Dra. Maria Cecília Dias     61         freitaslara@uol.com.br
# ...

# %%
reviews['linguagem'] = 'Python god'
reviews
# Out:
#                       nome  idade                           email  \
# 0              Samuel Melo     27       goncalvesdanilo@gmail.com
# 1         Henrique da Mata     60         jesusisadora@uol.com.br
# 2              Luigi Cunha     39            acarvalho@uol.com.br
# 3     Dra. Fernanda Novaes     29      ribeiropietra@yahoo.com.br
# 4         Joaquim Ferreira     60                 emelo@gmail.com
# ..                     ...    ...                             ...
# 195  Vitor Gabriel da Cruz     32              jbarros@uol.com.br
# 196       Letícia Silveira     20           jsilveira@pereira.org
# 197    Vitor Hugo Carvalho     65       rodriguesbreno@correia.br
# 198    Davi Lucas Nogueira     56        ada-conceicao@uol.com.br
# 199    Luiz Otávio Azevedo     43  maria-sophianogueira@lopes.net
#
#                   estado genero_musical   linguagem  invert
# 0         Espírito Santo          Blues  Python god     200
# ...

# %%
# invertendo index e colocando em uma coluna

reviews['invert'] = range(len(reviews), 0, -1)
reviews
# Out:
#                       nome  idade                           email  \
# 0              Samuel Melo     27       goncalvesdanilo@gmail.com
# 1         Henrique da Mata     60         jesusisadora@uol.com.br
# 2              Luigi Cunha     39            acarvalho@uol.com.br
# 3     Dra. Fernanda Novaes     29      ribeiropietra@yahoo.com.br
# 4         Joaquim Ferreira     60                 emelo@gmail.com
# ..                     ...    ...                             ...
# 195  Vitor Gabriel da Cruz     32              jbarros@uol.com.br
# 196       Letícia Silveira     20           jsilveira@pereira.org
# 197    Vitor Hugo Carvalho     65       rodriguesbreno@correia.br
# 198    Davi Lucas Nogueira     56        ada-conceicao@uol.com.br
# 199    Luiz Otávio Azevedo     43  maria-sophianogueira@lopes.net
#
#                   estado genero_musical   linguagem  invert
# 0         Espírito Santo          Blues  Python god     200
# ...
